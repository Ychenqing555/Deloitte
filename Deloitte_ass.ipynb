# %% [markdown]
# **Deloitte - Analyst, Reporting and Analytics position**
#
# 72-hour take-home project
#
# By Carl Chen Ychen555@uOttawa.ca

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-23f57a06-5c23-43a9-a011-656ede6a78df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23f57a06-5c23-43a9-a011-656ede6a78df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving uber-raw-data-may14.csv to uber-raw-data-may14.csv

# %%
import pandas as pd

# %%
df1 = pd.read_csv('uber-raw-data-may14.csv')

df1.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  5/1/2014 0:02:00  40.7521 -73.9914  B02512
# 1  5/1/2014 0:06:00  40.6965 -73.9715  B02512
# 2  5/1/2014 0:15:00  40.7464 -73.9838  B02512
# 3  5/1/2014 0:17:00  40.7463 -74.0011  B02512
# 4  5/1/2014 0:17:00  40.7594 -73.9734  B02512

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09432336-405e-40ef-b77a-acc295266733" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09432336-405e-40ef-b77a-acc295266733">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving uber-raw-data-jun14.csv to uber-raw-data-jun14.csv

# %%
df2 = pd.read_csv('uber-raw-data-jun14.csv')

df2.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  6/1/2014 0:00:00  40.7293 -73.9920  B02512
# 1  6/1/2014 0:01:00  40.7131 -74.0097  B02512
# 2  6/1/2014 0:04:00  40.3461 -74.6610  B02512
# 3  6/1/2014 0:04:00  40.7555 -73.9833  B02512
# 4  6/1/2014 0:07:00  40.6880 -74.1831  B02512

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-95fa1112-a882-44ab-84ec-2be51f16d778" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95fa1112-a882-44ab-84ec-2be51f16d778">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving uber-raw-data-jul14.csv to uber-raw-data-jul14.csv

# %%
df3 = pd.read_csv('uber-raw-data-jul14.csv')

df3.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  7/1/2014 0:03:00  40.7586 -73.9706  B02512
# 1  7/1/2014 0:05:00  40.7605 -73.9994  B02512
# 2  7/1/2014 0:06:00  40.7320 -73.9999  B02512
# 3  7/1/2014 0:09:00  40.7635 -73.9793  B02512
# 4  7/1/2014 0:20:00  40.7204 -74.0047  B02512

# %%
frames = [df1, df2, df3]

df = pd.concat(frames)

# %% [markdown]
# Save the table (union) into a working sheet as excel

# %%
# df.to_excel("uber-raw-data-3-month.xlsx")

df.to_csv('uber-raw-data-3-month')

# %%
files.download('uber-raw-data-3-month')

# %%
df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  5/1/2014 0:02:00  40.7521 -73.9914  B02512
# 1  5/1/2014 0:06:00  40.6965 -73.9715  B02512
# 2  5/1/2014 0:15:00  40.7464 -73.9838  B02512
# 3  5/1/2014 0:17:00  40.7463 -74.0011  B02512
# 4  5/1/2014 0:17:00  40.7594 -73.9734  B02512

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2112400 entries, 0 to 796120
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date/Time  object
#  1   Lat        float64
#  2   Lon        float64
#  3   Base       object
# dtypes: float64(2), object(2)
# memory usage: 80.6+ MB

# %%
df['Date/Time'] = df['Date/Time'].map(pd.to_datetime)

# %%
df.describe(include='all').T
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#                 count  unique                  top  ...      50%      75%      max
# Date/Time     2112400  130755  2014-06-13 18:03:00  ...      NaN      NaN      NaN
# Lat        2.1124e+06     NaN                  NaN  ...  40.7432  40.7612  41.3413
# Lon        2.1124e+06     NaN                  NaN  ... -73.9835 -73.9669 -72.1801
# Base          2112400       5               B02598  ...      NaN      NaN      NaN
#
# [4 rows x 13 columns]

# %%
df['Date/Time'].value_counts()
# Out:
# 2014-06-13 18:03:00    88
# 2014-07-15 19:30:00    79
# 2014-05-16 21:29:00    77
# 2014-05-16 19:58:00    77
# 2014-07-15 19:25:00    77
#                        ..
# 2014-05-21 02:22:00     1
# 2014-06-19 01:31:00     1
# 2014-06-19 01:43:00     1
# 2014-07-01 05:00:00     1
# 2014-05-23 01:30:00     1
# Name: Date/Time, Length: 130755, dtype: int64

# %%
df["Day"] = df["Date/Time"].apply(lambda x: x.day)
df["Weekday"] = df["Date/Time"].apply(lambda x: x.weekday())
df["Hour"] = df["Date/Time"].apply(lambda x: x.hour)

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  Day  Weekday  Hour
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512    1        3     0
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512    1        3     0
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512    1        3     0
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512    1        3     0
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512    1        3     0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(10, 5)})

# sns.distplot(df["Day"])

sns.countplot(x="Day",data=df)

# %%
ax = sns.countplot(x="Day", hue="Month", data=df)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

# sns.distplot(df["Hour"])
sns.countplot(x="Hour",data=df)

# %%
ax = sns.countplot(x="Hour", hue="Month", data=df)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

# sns.distplot(df["Hour"])
sns.countplot(x="Weekday",data=df)

# %%
ax = sns.countplot(x="Hour", hue="Month", data=df)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

sns.countplot(x="Hour", hue="Month", data=df)

# %%
df['Base']
# Out:
# 0         B02512
# 1         B02512
# 2         B02512
# 3         B02512
# 4         B02512
#            ...
# 796116    B02764
# 796117    B02764
# 796118    B02764
# 796119    B02764
# 796120    B02764
# Name: Base, Length: 2112400, dtype: object

# %%
sns.set(rc={'figure.figsize':(10, 5)})
sns.countplot(x= 'Base', data = df)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

sns.countplot(x= 'Month', data = df)

# %%
# df.groupby(by=['Date/Time']).count().plot(kind="bar")
# df.head()
# data['month'] = data['date'].dt.month
df['Month'] = df['Date/Time'].dt.month

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  Day  Weekday  Hour  Month
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512    1        3     0      5
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512    1        3     0      5
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512    1        3     0      5
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512    1        3     0      5
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512    1        3     0      5

# %%
# df.drop(columns=['month'], inplace=True)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

ax = sns.countplot(x="Base", hue="Month", data=df)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

ax = sns.countplot(x="Base", hue="Weekday", data=df)

# %%
sns.set(rc={'figure.figsize':(10, 5)})

ax = sns.countplot(x="Weekday", hue="Month", data=df)

# %%
# sns.distplot(df["Weekday"])

sns.countplot(x="Weekday",data=df)

# %% [markdown]
# In the above figure 0 indicates Sunday, on Sundays the Uber trips and more than Saturdays so we can say people also use Uber for outings rather than for just going to work. On Saturdays, the Uber trips are the lowest and on Thursday, they are the highest. Now let’s have a look at the correlation of hours and weekdays on the Uber trips:

# %%
df_new = df.groupby(["Weekday", "Hour"]).apply(lambda x: len(x))
df_new = df_new.unstack()
sns.heatmap(df_new, annot=False)

# %%
df_new = df.groupby(["Day", "Hour"]).apply(lambda x: len(x))
df_new = df_new.unstack()
sns.heatmap(df_new, annot=False)

# %%
df_new = df.groupby(["Weekday", "Base"]).apply(lambda x: len(x))
df_new = df_new.unstack()
sns.heatmap(df_new, annot=False)

# %%
df_new = df.groupby(["Month", "Base"]).apply(lambda x: len(x))
df_new = df_new.unstack()
sns.heatmap(df_new, annot=False)

# %%
# pip install geopandas

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

#  'Lon', y='Lat'

geometry = [Point(xy) for xy in zip(df['Lon'], df['Lat'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=5)

# %%
# https://thecleverprogrammer.com/2021/04/21/uber-trips-analysis-using-python/

# %%
df.plot(kind='scatter', x='Lon', y='Lat', alpha=0.4, s=df['Day'], label='Uber Trips',
figsize=(12, 8), cmap=plt.get_cmap('jet'))
plt.title("Uber Trips Analysis")
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df['Base'].value_counts()
# Out:
# B02598    749121
# B02617    617354
# B02682    614563
# B02512    104295
# B02764     27067
# Name: Base, dtype: int64

# %%
fig, ax = plt.subplots()
colors = {'B02598':'red', 'B02617':'green', 'B02682':'blue', 'B02512':'yellow', 'B02764': 'Yellow'}
ax.scatter(df['Lon'], df['Lat'], c=df['Base'].map(colors))
plt.show()

# %%
sns.lmplot('Lon', 'Lat', data=df, hue='Base', fit_reg=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
import csv

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  ...  Weekday  Hour  Month  isRain
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512  ...        3     0      5    True
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512  ...        3     0      5    True
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512  ...        3     0      5    True
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512  ...        3     0      5    True
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512  ...        3     0      5    True
#
# [5 rows x 9 columns]

# %%
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = df[['Lat']]
X_axis = df[['Lon']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
# NY Weather Data - Apr 14 - Jul 14.xlsx
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-55f1a0e5-ca72-43a7-ae37-70094b8e4e73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55f1a0e5-ca72-43a7-ae37-70094b8e4e73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NY_Weather_Data-Apr-14-Jul-14.xlsx to NY_Weather_Data-Apr-14-Jul-14.xlsx

# %%
weahter_may = pd.read_excel('NY_Weather_Data-Apr-14-Jul-14.xlsx', sheet_name='May')


weahter_may.head()
# Out:
#    May  high  avg  low  high.1  ...  high.5  avg.5  high.6   sum  Unnamed: 20
# 0    1    22   17   12      16  ...      37     21      48   6.1   Fog , Rain
# 1    2    21   16   11      11  ...      39     18      45  0.25         Rain
# 2    3    19   14    9      10  ...      37     16      45     T         Rain
# 3    4    19   16   12       9  ...      52     30      71     T          NaN
# 4    5    21   16   10       2  ...      53     27      69     0          NaN
#
# [5 rows x 21 columns]

# %%
weahter_may.rename(columns={'May': 'Date'}, inplace=True )
# Date/Time 
weahter_may.head()
# Out:
#    Date  high  avg  low  high.1  ...  high.5  avg.5  high.6   sum  Unnamed: 20
# 0     1    22   17   12      16  ...      37     21      48   6.1   Fog , Rain
# 1     2    21   16   11      11  ...      39     18      45  0.25         Rain
# 2     3    19   14    9      10  ...      37     16      45     T         Rain
# 3     4    19   16   12       9  ...      52     30      71     T          NaN
# 4     5    21   16   10       2  ...      53     27      69     0          NaN
#
# [5 rows x 21 columns]

# %%
weahter_may.rename(columns={'Unnamed: 20': 'isRain'}, inplace=True )

# %%
weahter_may.head()
# Out:
#    Date  high  avg  low  high.1  ...  high.5  avg.5  high.6   sum      isRain
# 0     1    22   17   12      16  ...      37     21      48   6.1  Fog , Rain
# 1     2    21   16   11      11  ...      39     18      45  0.25        Rain
# 2     3    19   14    9      10  ...      37     16      45     T        Rain
# 3     4    19   16   12       9  ...      52     30      71     T         NaN
# 4     5    21   16   10       2  ...      53     27      69     0         NaN
#
# [5 rows x 21 columns]

# %%
list1 = weahter_may[weahter_may['isRain'].notnull()]['Date'].values.tolist()
list1
# Out:
# [1, 2, 3, 8, 9, 10, 11, 15, 16, 17, 22, 23, 24, 30]

# %%
day_check = True 
df['isRain'] = ''

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  ...  Weekday  Hour  Month  isRain
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512  ...        3     0      5
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512  ...        3     0      5
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512  ...        3     0      5
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512  ...        3     0      5
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512  ...        3     0      5
#
# [5 rows x 9 columns]

# %% [markdown]
# Label May data with 'isRain' column

# %%
df.loc[(df['Month'] == 5), 'isRain'] = False

# %%
# may rain date is [1, 2, 3, 8, 9, 10, 11, 15, 16, 17, 22, 23, 24, 30]
# list1 
# 
for i in range(len(list1)):
  # df[(df['Month'] == 5) &  (df['Day'] == i)].loc['isRain'] = True
  df.loc[(df['Month'] == 5) &  (df['Day'] == list1[i]), 'isRain'] = True
  # print(list1[i])

df
# Out:
#                  Date/Time      Lat      Lon  ... Hour  Month  isRain
# 0      2014-05-01 00:02:00  40.7521 -73.9914  ...    0      5    True
# 1      2014-05-01 00:06:00  40.6965 -73.9715  ...    0      5    True
# 2      2014-05-01 00:15:00  40.7464 -73.9838  ...    0      5    True
# 3      2014-05-01 00:17:00  40.7463 -74.0011  ...    0      5    True
# 4      2014-05-01 00:17:00  40.7594 -73.9734  ...    0      5    True
# ...                    ...      ...      ...  ...  ...    ...     ...
# 796116 2014-07-31 23:22:00  40.7285 -73.9846  ...   23      7   False
# 796117 2014-07-31 23:23:00  40.7615 -73.9868  ...   23      7   False
# 796118 2014-07-31 23:29:00  40.6770 -73.9515  ...   23      7   False
# 796119 2014-07-31 23:30:00  40.7225 -74.0038  ...   23      7   False
# 796120 2014-07-31 23:58:00  40.7199 -73.9884  ...   23      7   False
#
# [2112400 rows x 9 columns]

# %% [markdown]
# Similarly, deal with **join** the other two weather tables with uber data (on date)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bfe74d05-bd6c-47a9-aac5-7b7b5b2be1f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfe74d05-bd6c-47a9-aac5-7b7b5b2be1f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NY_Weather_Data-3-sheets.xlsx to NY_Weather_Data-3-sheets.xlsx

# %%
weahter_july = pd.read_excel('NY_Weather_Data-3-sheets.xlsx', sheet_name='July')

# %%
weahter_jun = pd.read_excel('NY_Weather_Data-3-sheets.xlsx', sheet_name='Jun')

# %%
weahter_jun.rename(columns={'Unnamed: 20': 'isRain'}, inplace=True )

# %%
weahter_jun.rename(columns={'Jun': 'Date'}, inplace=True )
weahter_jun.head()
# Out:
#    Date  high  avg  low  high.1  ...  high.5  avg.5  high.6   sum  isRain
# 0     1    24   18   12       9  ...      23     13      26     0     NaN
# 1     2    23   19   14      14  ...      35     16      42     0     NaN
# 2     3    27   22   17      19  ...      35     12      66     T    Rain
# 3     4    28   23   17      17  ...      34     12      60     T     NaN
# 4     5    25   21   17      17  ...      37     20      50  12.7    Rain
#
# [5 rows x 21 columns]

# %%
weahter_july.rename(columns={'Unnamed: 20': 'isRain'}, inplace=True )
weahter_july.rename(columns={'Jul': 'Date'}, inplace=True )

# %%
weahter_july.head()
# Out:
#    Date  high  avg  low  ...  avg.5  high.6    sum               isRain
# 0     1    29   26   22  ...     24      61      0                  NaN
# 1     2    29   26   22  ...     19      60  13.21  Rain , Thunderstorm
# 2     3    29   26   22  ...     14      56   8.89  Rain , Thunderstorm
# 3     4    24   22   19  ...     24      66   8.13                 Rain
# 4     5    29   24   18  ...     22      50      0                  NaN
#
# [5 rows x 21 columns]

# %%
weahter_july['isRain'].value_counts()
# Out:
# Rain                   7
# Rain , Thunderstorm    7
# Fog                    1
# Name: isRain, dtype: int64

# %%
weahter_may['isRain'].value_counts()
# Out:
# Rain                         9
# Fog , Rain                   2
# Rain , Thunderstorm          2
# Fog , Rain , Thunderstorm    1
# Name: isRain, dtype: int64

# %%
weahter_jun['isRain'].value_counts()
# Out:
# Rain                         6
# Fog , Rain , Thunderstorm    1
# Rain , Thunderstorm          1
# Name: isRain, dtype: int64

# %%
list2 = weahter_jun[weahter_jun['isRain'].notnull()]['Date'].values.tolist()
print(list2)

list3 = weahter_july[weahter_july['isRain'].notnull()]['Date'].values.tolist()
list3
# Out:
# [3, 5, 9, 11, 12, 13, 19, 26]
# [2, 3, 4, 10, 12, 13, 14, 15, 16, 20, 23, 24, 26, 27, 28]

# %%
df.loc[(df['Month'] == 6), 'isRain'] = False

for i in range(len(list3)):
  df.loc[(df['Month'] == 6) &  (df['Day'] == list3[i]), 'isRain'] = True

df.head()
# Out:
#             Date/Time      Lat      Lon    Base  ...  Weekday  Hour  Month  isRain
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512  ...        3     0      5    True
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512  ...        3     0      5    True
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512  ...        3     0      5    True
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512  ...        3     0      5    True
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512  ...        3     0      5    True
#
# [5 rows x 9 columns]

# %%
df.loc[(df['Month'] == 7), 'isRain'] = False

# %%
for i in range(len(list3)):
  df.loc[(df['Month'] == 7) &  (df['Day'] == list3[i]), 'isRain'] = True

df.head()
# Out:
#             Date/Time      Lat      Lon    Base  ...  Weekday  Hour  Month  isRain
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512  ...        3     0      5   False
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512  ...        3     0      5   False
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512  ...        3     0      5   False
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512  ...        3     0      5   False
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512  ...        3     0      5   False
#
# [5 rows x 9 columns]

# %%
sns.set(rc={'figure.figsize':(20, 5)})
sns.countplot(x="Day",hue='isRain', data=df[df['Month'] == 5 ])
# [1, 2, 3, 8, 9, 10, 11, 15, 16, 17, 22, 23, 24, 30]

# %%
sns.set(rc={'figure.figsize':(20, 5)})
sns.countplot(x="Day",hue='isRain', data=df[df['Month'] == 6 ])


# [3, 5, 9, 11, 12, 13, 19, 26]

# %%
sns.set(rc={'figure.figsize':(20, 5)})
sns.countplot(x="Day",hue='isRain', data=df[df['Month'] == 7])
# [2, 3, 4, 10, 12, 13, 14, 15, 16, 20, 23, 24, 26, 27, 28]

# %%
import scipy.stats

r = scipy.stats.pearsonr(df["Day"], df['isRain'])    # Pearson's r
r[1]
# Out:
# 0.0

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  ...  Weekday  Hour  Month  isRain
# 0 2014-05-01 00:02:00  40.7521 -73.9914  B02512  ...        3     0      5    True
# 1 2014-05-01 00:06:00  40.6965 -73.9715  B02512  ...        3     0      5    True
# 2 2014-05-01 00:15:00  40.7464 -73.9838  B02512  ...        3     0      5    True
# 3 2014-05-01 00:17:00  40.7463 -74.0011  B02512  ...        3     0      5    True
# 4 2014-05-01 00:17:00  40.7594 -73.9734  B02512  ...        3     0      5    True
#
# [5 rows x 9 columns]

# %%
sns.countplot(x="Day", data=df[df['Month'] == 5 ])

# %% [markdown]
# May 11, 24 is strange!

# %%
# weahter_may[weahter_may['Date'] == 11]
# weahter_may['high']

sns.countplot(x = 'high', data = weahter_may )

# %%
# weahter_may['Date']

plt.plot(weahter_may['Date'],  weahter_may['high'])

# %%
plt.plot(weahter_may['Date'],  weahter_may['avg'])
